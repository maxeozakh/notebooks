# %%
from fastai.vision.all import *
from ipywidgets import widgets

# %%
# https://www.kaggle.com/datasets/somesh24/multiclass-images-for-weather-classification
# todo: download it instead of having locally
path = Path('../data_weather')
image_files = get_image_files(path)

# %%
def get_label_from_filename(file_path):
    return ''.join([char for char in file_path.split('_')[0] if not char.isdigit()])[:-4]

# %%
dls = ImageDataLoaders.from_name_func(
    path,
    get_image_files(path),         # Get all image files
    label_func=get_label_from_filename,  # Custom function for labels
    valid_pct=0.2,                 # Split 20% of data as validation set
    item_tfms=Resize(224)          # Resize all images to 224x224
)
dls.show_batch(max_n=6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dls = ImageDataLoaders.from_name_func(
#       2     path,
#       3     get_image_files(path),         # Get all image files
#       4     label_func=get_label_from_filename,  # Custom function for labels
#       5     valid_pct=0.2,                 # Split 20% of data as validation set
#       6     item_tfms=Resize(224)          # Resize all images to 224x224
#       7 )
#       8 dls.show_batch(max_n=6)
#
# File ~/venv/lib/python3.11/site-packages/fastai/vision/data.py:150, in ImageDataLoaders.from_name_func(cls, path, fnames, label_func, **kwargs)
#     148     raise ValueError("label_func couldn't be lambda function on Windows")
#     149 f = using_attr(label_func, 'name')
# --> 150 return cls.from_path_func(path, fnames, f, **kwargs)
#
# File ~/venv/lib/python3.11/site-packages/fastai/vision/data.py:136, in ImageDataLoaders.from_path_func(cls, path, fnames, label_func, valid_pct, seed, item_tfms, batch_tfms, img_cls, **kwargs)
#     130 "Create from list of `fnames` in `path`s with `label_func`"
#     131 dblock = DataBlock(blocks=(ImageBlock(img_cls), CategoryBlock),
#     132                    splitter=RandomSplitter(valid_pct, seed=seed),
#     133                    get_y=label_func,
#     134                    item_tfms=item_tfms,
#     135                    batch_tfms=batch_tfms)
# --> 136 return cls.from_dblock(dblock, fnames, path=path, **kwargs)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/core.py:280, in DataLoaders.from_dblock(cls, dblock, source, path, bs, val_bs, shuffle, device, **kwargs)
#     269 @classmethod
#     270 def from_dblock(cls,
#     271     dblock, # `DataBlock` object
#    (...)    278     **kwargs
#     279 ):
# --> 280     return dblock.dataloaders(source, path=path, bs=bs, val_bs=val_bs, shuffle=shuffle, device=device, **kwargs)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/block.py:157, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     151 def dataloaders(self,
#     152     source, # The data source
#     153     path:str='.', # Data source and default `Learner` path
#     154     verbose:bool=False, # Show verbose messages
#     155     **kwargs
#     156 ) -> DataLoaders:
# --> 157     dsets = self.datasets(source, verbose=verbose)
#     158     kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
#     159     return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/block.py:149, in DataBlock.datasets(self, source, verbose)
#     147 splits = (self.splitter or RandomSplitter())(items)
#     148 pv(f"{len(splits)} datasets of sizes {','.join([str(len(s)) for s in splits])}", verbose)
# --> 149 return Datasets(items, tfms=self._combine_type_tfms(), splits=splits, dl_type=self.dl_type, n_inp=self.n_inp, verbose=verbose)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/core.py:450, in Datasets.__init__(self, items, tfms, tls, n_inp, dl_type, **kwargs)
#     441 def __init__(self,
#     442     items:list=None, # List of items to create `Datasets`
#     443     tfms:MutableSequence|Pipeline=None, # List of `Transform`(s) or `Pipeline` to apply
#    (...)    447     **kwargs
#     448 ):
#     449     super().__init__(dl_type=dl_type)
# --> 450     self.tls = L(tls if tls else [TfmdLists(items, t, **kwargs) for t in L(ifnone(tfms,[None]))])
#     451     self.n_inp = ifnone(n_inp, max(1, len(self.tls)-1))
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/core.py:450, in <listcomp>(.0)
#     441 def __init__(self,
#     442     items:list=None, # List of items to create `Datasets`
#     443     tfms:MutableSequence|Pipeline=None, # List of `Transform`(s) or `Pipeline` to apply
#    (...)    447     **kwargs
#     448 ):
#     449     super().__init__(dl_type=dl_type)
# --> 450     self.tls = L(tls if tls else [TfmdLists(items, t, **kwargs) for t in L(ifnone(tfms,[None]))])
#     451     self.n_inp = ifnone(n_inp, max(1, len(self.tls)-1))
#
# File ~/venv/lib/python3.11/site-packages/fastcore/foundation.py:105, in _L_Meta.__call__(cls, x, *args, **kwargs)
#     103 def __call__(cls, x=None, *args, **kwargs):
#     104     if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 105     return super().__call__(x, *args, **kwargs)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/core.py:364, in TfmdLists.__init__(self, items, tfms, use_list, do_setup, split_idx, train_setup, splits, types, verbose, dl_type)
#     362 if do_setup:
#     363     pv(f"Setting up {self.tfms}", verbose)
# --> 364     self.setup(train_setup=train_setup)
#
# File ~/venv/lib/python3.11/site-packages/fastai/data/core.py:393, in TfmdLists.setup(self, train_setup)
#     391         x = f(x)
#     392     self.types.append(type(x))
# --> 393 types = L(t if is_listy(t) else [t] for t in self.types).concat().unique()
#     394 self.pretty_types = '\n'.join([f'  - {t}' for t in types])
#
# TypeError: 'NoneType' object is not iterable

# %%
# Create a learner using a pre-trained resnet34 model
learn = vision_learner(dls, resnet34, metrics=accuracy)

# %%
learn.fine_tune(1)

# Show results on a batch of the validation set
learn.show_results(max_n=6)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.761668</td>
#       <td>0.263764</td>
#       <td>0.920000</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.323942</td>
#       <td>0.138174</td>
#       <td>0.964444</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
if uploader.data:
    img = PILImage.create(uploader.data[0])
    img.show()

    # Make a prediction using the trained model
    pred, pred_idx, probs = learn.predict(img)
    print(f"Prediction: {pred}")
    print(f"Confidence: {probs[pred_idx]:.4f}")
else:
    print("Upload an image. Faster, now")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction: sunrise.
# Confidence: 0.9999
